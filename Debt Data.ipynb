# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/hygj10/Data-Bootcamp-Final-Project/master/debt.csv"
df = pd.read_csv(url)
df.columns = df.iloc[0]
df = df.shift(-1)
df.head(10)
# Out:
# 0 Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
# 5  Afghanistan          AFG
# 6  Afghanistan          AFG
# 7  Afghanistan          AFG
# 8  Afghanistan          AFG
# 9  Afghanistan          AFG
#
# 0                                     Indicator Name Indicator Code  1970.0  \
# 0  Average grace period on new external debt comm...    DT.GPA.DPPG     NaN
# 1  Average grace period on new external debt comm...    DT.GPA.OFFT     NaN
# 2  Average grace period on new external debt comm...    DT.GPA.PRVT     NaN
# 3  Average grant element on new external debt com...    DT.GRE.DPPG     NaN
# 4  Average grant element on new external debt com...    DT.GRE.OFFT     NaN
# 5  Average grant element on new external debt com...    DT.GRE.PRVT     NaN
# 6  Average interest on new external debt commitme...    DT.INR.DPPG     NaN
# ...
